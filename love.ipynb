# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaaishah/love/blob/main/love.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
from matplotlib import pyplot as plt
GAP = 76
# Creating equally spaced data in range 0 to 2*pi
theta = np.linspace(0, 2 * np.pi, GAP)
# Generating x and y data
x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)
# Plotting
plt.plot(x,y)
plt.title('Shape')
plt.show()
